Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_108_5.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   369K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_108_6.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   343K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_108_7.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   325K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_108_8.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   352K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_108_9.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   334K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_109_0.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   331K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_109_1.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   349K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_109_2.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   349K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_109_3.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   390K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_109_4.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   356K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_109_5.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   335K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_109_6.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   337K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_109_7.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   386K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_109_8.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   312K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_109_9.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   365K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_110_0.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   288K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_110_1.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   342K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_110_2.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   321K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_110_3.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   434K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_110_4.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   378K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_110_5.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   387K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_110_6.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   381K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_110_7.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   360K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_110_8.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   341K Apr  3  2022 input_suep_v2/suep_gensim_h125_phi2_dp0p7_dt2_110_9.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   2.9M Apr  5  2022 input_suep_v2/suep_gensim_h1000_phi2_dp0p7_dt2_102_0.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   3.0M Apr  5  2022 input_suep_v2/suep_gensim_h1000_phi2_dp0p7_dt2_102_1.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   2.9M Apr  5  2022 input_suep_v2/suep_gensim_h1000_phi2_dp0p7_dt2_102_2.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   2.9M Apr  5  2022 input_suep_v2/suep_gensim_h1000_phi2_dp0p7_dt2_102_3.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   3.0M Apr  5  2022 input_suep_v2/suep_gensim_h1000_phi2_dp0p7_dt2_102_4.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   3.3M Apr  5  2022 input_suep_v2/suep_gensim_h1000_phi2_dp0p7_dt2_102_5.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   3.1M Apr  5  2022 input_suep_v2/suep_gensim_h1000_phi2_dp0p7_dt2_102_6.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   3.1M Apr  5  2022 input_suep_v2/suep_gensim_h1000_phi2_dp0p7_dt2_102_7.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   3.2M Apr  5  2022 input_suep_v2/suep_gensim_h1000_phi2_dp0p7_dt2_102_8.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   3.1M Apr  5  2022 input_suep_v2/suep_gensim_h1000_phi2_dp0p7_dt2_102_9.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   3.1M Apr  5  2022 input_suep_v2/suep_gensim_h1000_phi2_dp0p7_dt2_103_0.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   3.0M Apr  5  2022 input_suep_v2/suep_gensim_h1000_phi2_dp0p7_dt2_103_1.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   3.5M Apr  5  2022 input_suep_v2/suep_gensim_h1000_phi2_dp0p7_dt2_103_2.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   3.5M Apr  5  2022 input_suep_v2/suep_gensim_h1000_phi2_dp0p7_dt2_103_3.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   3.0M Apr  5  2022 input_suep_v2/suep_gensim_h1000_phi2_dp0p7_dt2_103_4.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   2.9M Apr  5  2022 input_suep_v2/suep_gensim_h1000_phi2_dp0p7_dt2_103_5.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   3.4M Apr  5  2022 input_suep_v2/suep_gensim_h1000_phi2_dp0p7_dt2_103_6.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   3.1M Apr  5  2022 input_suep_v2/suep_gensim_h1000_phi2_dp0p7_dt2_103_7.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   3.1M Apr  5  2022 input_suep_v2/suep_gensim_h1000_phi2_dp0p7_dt2_103_8.h5
# -rw-r--r--  1 simranjitsinghchhibra  staff   3.0M Apr  5  2022 input_suep_v2/suep_gensim_h1000_phi2_dp0p7_dt2_103_9.h5

# %%
#GENERATOR 

def get_file_list(path):
    flist = []
    flist += glob.glob(path + '/' + '*101_0*.h5')
    flist.sort()
    print("flist: ", flist)
    return flist

def read_images_from_file(fname):
    print("Appending %s" %fname)
    with h5py.File(fname,'r') as f:
        ImageTrk  = np.array(f.get("ImageTrk_PUcorr")[:10], dtype=np.float16)
        ImageTrk  = ImageTrk.reshape(ImageTrk.shape[0], ImageTrk.shape[1], ImageTrk.shape[2], 1)

        ImageECAL = np.array(f.get("ImageECAL")[:10], dtype=np.float16)
        ImageECAL = ImageECAL.reshape(ImageECAL.shape[0], ImageECAL.shape[1], ImageECAL.shape[2], 1)

        ImageHCAL = np.array(f.get("ImageHCAL")[:10], dtype=np.float16)
        ImageHCAL = ImageHCAL.reshape(ImageHCAL.shape[0], ImageHCAL.shape[1], ImageHCAL.shape[2], 1)

        Image3D = np.concatenate([ImageTrk, ImageECAL, ImageHCAL], axis=-1)

        Image3D_zero = np.zeros((Image3D.shape[0], 288, 360, 3), dtype=np.float16)
        Image3D_zero[:, 1:287, :, :] += Image3D
        Image3D_zero = np.divide(Image3D_zero, 2000., dtype=np.float16)
        return Image3D_zero

def concatenate_by_file_content(Image3D, fname):
    Image3D_tmp = read_images_from_file(fname)
    Image3D = np.concatenate([Image3D, Image3D_tmp], axis=0) if Image3D.size else Image3D_tmp
    return Image3D

def gen(parts_n, pathindex):

    if   (pathindex == 0): flist = get_file_list("input_qcd_v2")
    elif (pathindex == 1): flist = get_file_list("input_qcd_v2"  )

    Image3D_conc = np.array([])
    
    for i_file, fname in enumerate(flist):
        Image3D_conc = concatenate_by_file_content(Image3D_conc, fname)

        while (len(Image3D_conc) >= parts_n):
            Image3D_part, Image3D_conc = Image3D_conc[:parts_n] , Image3D_conc[parts_n:]
            print (" K.sum ", np.sum(Image3D_part[0]))                                                                                                                                                                     
            #print (" ",Image3D_part.shape, Image3D_conc.shape)
            
            Image3D_part_tf = tf.convert_to_tensor(Image3D_part, dtype=tf.float16)
            yield (Image3D_part_tf, Image3D_part_tf)


parts = 1
dataset_train = tf.data.Dataset.from_generator(
    gen,
    args=[parts, 0],
    output_types=(tf.float16, tf.float16))

dataset_val = tf.data.Dataset.from_generator(
    gen,
    args=[parts, 1],
    output_types=(tf.float16, tf.float16))

# %%
#MODEL

img_rows = 288
img_cols = 360
img_chns = 3

############ENCODER                                                                                                                                                                                                        
inputImage = Input(shape=(img_rows, img_cols, img_chns))
x1 = Conv2D(128, (3,3), strides=(3, 3), padding="same")(inputImage)
x2 = BatchNormalization()(x1)
x3 = PReLU()(x2)
x4 = Conv2D(64, (3,3), strides=(2, 2), padding="same")(x3)
x5 = BatchNormalization()(x4)
x6 = PReLU()(x5)
x7 = Conv2D(32, (3,3), strides=(2, 2), padding="same")(x6)
x8 = BatchNormalization()(x7)
x9 = PReLU()(x8)
x10 = Conv2D(16, (3,3), strides=(2, 2), padding="same")(x9)
x11 = BatchNormalization()(x10)
x12 = PReLU()(x11)
x13 = Conv2D(8, (3,3), strides=(2, 3), padding="same")(x12)
x14 = BatchNormalization()(x13)
encoder_output = PReLU()(x14)

############DECODER                                                                                                                                                                                                       \
                                                                                                                                                                                                                           
x15 = Conv2DTranspose(16, (3,3), strides=(2, 3), padding="same")(encoder_output)
x16 = BatchNormalization()(x15)
x17 = PReLU()(x16)
x18 = Conv2DTranspose(32, (3,3), strides=(2, 2), padding="same")(x17)
x19 = BatchNormalization()(x18)
x20 = PReLU()(x19)
x21 = Conv2DTranspose(64, (3,3), strides=(2, 2), padding="same")(x20)
x22 = BatchNormalization()(x21)
x23 = PReLU()(x22)
x24 = Conv2DTranspose(128, (3,3), strides=(2, 2), padding="same")(x23)
x25 = BatchNormalization()(x24)
x26 = PReLU()(x25)
x27 = Conv2DTranspose(img_chns, (3,3), strides=(3, 3), padding="same")(x26)
x28 = BatchNormalization()(x27)
output = Activation('relu')(x28)

model = Model(inputs=inputImage, outputs=output)
encoder = Model(inputs=inputImage, outputs=encoder_output)

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 288, 360, 3)]     0
#
#  conv2d_5 (Conv2D)           (None, 96, 120, 128)      3584
#
#  batch_normalization_10 (Bat  (None, 96, 120, 128)     512
#  chNormalization)
#
#  p_re_lu_9 (PReLU)           (None, 96, 120, 128)      1474560
#
#  conv2d_6 (Conv2D)           (None, 48, 60, 64)        73792
#
#  batch_normalization_11 (Bat  (None, 48, 60, 64)       256
#  chNormalization)
#
#  p_re_lu_10 (PReLU)          (None, 48, 60, 64)        184320
#
#  conv2d_7 (Conv2D)           (None, 24, 30, 32)        18464
#
#  batch_normalization_12 (Bat  (None, 24, 30, 32)       128
#  chNormalization)
#
#  p_re_lu_11 (PReLU)          (None, 24, 30, 32)        23040
#
#  conv2d_8 (Conv2D)           (None, 12, 15, 16)        4624
#
#  batch_normalization_13 (Bat  (None, 12, 15, 16)       64
#  chNormalization)
#
#  p_re_lu_12 (PReLU)          (None, 12, 15, 16)        2880
#
#  conv2d_9 (Conv2D)           (None, 6, 5, 8)           1160
#
#  batch_normalization_14 (Bat  (None, 6, 5, 8)          32
#  chNormalization)
#
#  p_re_lu_13 (PReLU)          (None, 6, 5, 8)           240
#
#  conv2d_transpose_5 (Conv2DT  (None, 12, 15, 16)       1168
#  ranspose)
#
#  batch_normalization_15 (Bat  (None, 12, 15, 16)       64
#  chNormalization)
#
#  p_re_lu_14 (PReLU)          (None, 12, 15, 16)        2880
#
#  conv2d_transpose_6 (Conv2DT  (None, 24, 30, 32)       4640
#  ranspose)
#
#  batch_normalization_16 (Bat  (None, 24, 30, 32)       128
#  chNormalization)
#
#  p_re_lu_15 (PReLU)          (None, 24, 30, 32)        23040
#
#  conv2d_transpose_7 (Conv2DT  (None, 48, 60, 64)       18496
#  ranspose)
#
#  batch_normalization_17 (Bat  (None, 48, 60, 64)       256
#  chNormalization)
#
#  p_re_lu_16 (PReLU)          (None, 48, 60, 64)        184320
#
#  conv2d_transpose_8 (Conv2DT  (None, 96, 120, 128)     73856
#  ranspose)
#
#  batch_normalization_18 (Bat  (None, 96, 120, 128)     512
#  chNormalization)
#
#  p_re_lu_17 (PReLU)          (None, 96, 120, 128)      1474560
#
#  conv2d_transpose_9 (Conv2DT  (None, 288, 360, 3)      3459
#  ranspose)
#
#  batch_normalization_19 (Bat  (None, 288, 360, 3)      12
#  chNormalization)
#
#  activation_1 (Activation)   (None, 288, 360, 3)       0
#
# =================================================================
# Total params: 3,575,047
# Trainable params: 3,574,065
# Non-trainable params: 982
# _________________________________________________________________

# %%
LEARNING_RATE = 0.0005 #2 times smaller than default 0.001                                                                                                                                                                 
n_epochs = 1
batch_size = parts
opt = Adam(learning_rate = LEARNING_RATE)

#tf.config.run_functions_eagerly(True)

def DiceLoss(y_true, y_pred, smooth=1e-6):
    dice = []
    for i in range(parts):
        y_true_tmp = tf.reshape(y_true[i], shape=(1, (288*360*3)))
        y_pred_tmp = tf.reshape(y_pred[i], shape=(1, (288*360*3)))

        idx_keep_in = tf.where(y_true_tmp[0,:]!=0)[:,-1]
        y_true_tmp  = tf.gather(y_true_tmp[0,:], idx_keep_in)
        y_pred_tmp  = tf.gather(y_pred_tmp[0,:], idx_keep_in)

        y_true_tmp = tf.reshape(y_true_tmp, shape=(1, y_true_tmp.shape[0]))
        y_pred_tmp = tf.reshape(y_pred_tmp, shape=(y_pred_tmp.shape[0], 1))

        intersection = K.sum(K.dot(y_true_tmp, y_pred_tmp))
        dice.append(1 - (2 * intersection + smooth) / (K.sum(y_true[i]) + K.sum(y_pred[i]) + smooth))
    return dice

def intersection(targets, inputs):

    inputs = tf.reshape(inputs, shape=((parts*288*360*3), 1))
    targets = tf.reshape(targets, shape=(1, (parts*288*360*3)))

    return K.sum(K.dot(targets, inputs))

def sum_y_true(y_true, y_pred):
#    return K.sum(y_true, axis=[1,2,3])
    return K.sum(y_true)

def sum_y_pred(y_true, y_pred):
    return K.sum(y_pred, axis=[1,2,3])

# %%
model.compile(optimizer=opt, loss = DiceLoss, metrics=[intersection, sum_y_true, sum_y_pred])

# %%
history = model.fit(dataset_train, epochs=n_epochs, initial_epoch = 0, batch_size=batch_size,# steps_per_epoch=100,                                                                                                        
                    validation_data=dataset_val,
                    callbacks = [
                        EarlyStopping(monitor='val_loss', patience=5, verbose=1, min_delta=0.0001),
                        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1),
                        TerminateOnNaN()])
